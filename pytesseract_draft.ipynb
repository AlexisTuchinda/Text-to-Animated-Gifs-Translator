# %%
from PIL import Image
import pytesseract

pytesseract.tesseract_cmd = r"C:/opt/homebrew/bin/tesseract"
image_path = r"test_images/pytesseract-page5.png"

image = Image.open(image_path)
text = pytesseract.image_to_string(image)
print (text[:-1])
print ("finished")
# Out:
# °
#
# Calculus
# 2022- 2023
#
# Test #1.1: Limits
#
# Please sj
# 9N bel a
# ©W Certifying the statement of Academic Integrity and turn it in.
#
# This test is
# m
# Y Own independent work without the use of technology or any other resources.
#
# Math 4 - Fall 2022- Course Rubric
# oe standard scoring descriptions:
# - ( ‘ommendation) Student work shows evidence of especially sophisticated, nuanced, or
#
# analytical thinking.
# 3 - et) Student demonstrates mastery of the standards assessed.
# : ~ (Partial mastery) Student demonstrates partial mastery of the standards assessed.
#
# - (Emerging understanding) Student demonstrates emerging understanding of the standards
# assessed.
# 1 - (Insufficient evidence) Student has submitted insufficient
#
# X +4 \- pak ) Da.
# Name: BAcxis ay osc 43. ae
# St ime: ; class) Date: 4-Ib -
# art Time: A® Cn Glass) FiniSh Time: linc a s)
# AACE) Lext va Hue
#
# ein ork puch, aoe ee Eee a a ae
# ? ; ni %
# 4 j 4
#
# AR
#
# evidence for the standards assessed.
#
# eas POE
#
# Sy
#
# ay Par
# . we B27 Lae
#
# ee erg te 5
# e
# = v
#
# Limits and epsilon delta proofs
#
# Understand one sided and two sided limits.
#
# State and apply the definition of limit.
#
# Understand when a function is undefined.
# Calculate infinite limits, limits at undefined points and limits at infinity graphically and
#
# numerically. : oi. a :
# -|Calculate infinite limits, limits at undefined points and limits at infinity algebraically.
#
# [state and apply the limit laws to solve a problem
#
# Evaluate trigonometric limits.
#
# State. and apply the squeeze theorem (sandwich theorem). | ara |
#
# State ‘the precise definition of a limit and illustrate the concept of an epsilon-delta proof
#
# using simple limits. | .
# Evaluate limits using the definition of e.”
# Write an epsilon-delta proof to prove simple limits. *
#
# Intermediate Value Theorem and Boundedness Theorem
#
# Continuity,
# Identify the types of discontinuity ae
# Define continuity and apply the definition of continuity to solve problems
#
# | stare and apply intermediate value theorem
#
# State and apply boundedness theorem*
#
# Veena Krishnan, Roya Curtis and Mathhew Gil
#
# September 2022
# finished
